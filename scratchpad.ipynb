# %%
import pandas as pd

# %%
df = pd.read_csv("CH_stim_SPK_data.csv")
df
# Out:
#     Channel stim_cond  SPK_count
# 0     A-001         a          5
# 1     A-002         a          4
# 2     A-003         a          8
# 3     A-004         a          6
# 4     A-005         a          0
# ..      ...       ...        ...
# 195   A-001         e          4
# 196   A-002         e          3
# 197   A-003         e          7
# 198   A-004         e          6
# 199   A-005         e          1
#
# [200 rows x 3 columns]

# %%
gf = df.groupby('Channel')
# df.groupby('team').apply(lambda x: x['team'].count() / df.shape[0])

# %%
gf.groups.keys()
# Out:
# dict_keys(['A-001', 'A-002', 'A-003', 'A-004', 'A-005'])

# %%
for name, group in gf:
    print(name)
    display(group)

# %%
df1 = gf.get_group('A-001').groupby(['Channel','stim_cond'])['SPK_count'].aggregate('sum')
df1
# Out:
# Channel  stim_cond
# A-001    a            15
#          b            12
#          c             7
#          d             7
#          e            12
# Name: SPK_count, dtype: int64

# %%
gf1 = df.groupby(['Channel','stim_cond'])['SPK_count'].aggregate('sum').reset_index()

gf1 = pd.DataFrame(gf1)
gf1
# Out:
#    Channel stim_cond  SPK_count
# 0    A-001         a         15
# 1    A-001         b         12
# 2    A-001         c          7
# 3    A-001         d          7
# 4    A-001         e         12
# 5    A-002         a         16
# 6    A-002         b          9
# 7    A-002         c          9
# 8    A-002         d         16
# 9    A-002         e          9
# 10   A-003         a         42
# 11   A-003         b         51
# 12   A-003         c         40
# 13   A-003         d         47
# 14   A-003         e         51
# 15   A-004         a         24
# 16   A-004         b         31
# 17   A-004         c         27
# 18   A-004         d         39
# 19   A-004         e         44
# 20   A-005         a          2
# 21   A-005         b          5
# 22   A-005         c          5
# 23   A-005         d          3
# 24   A-005         e          4
