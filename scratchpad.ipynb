# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("CH_stim_SPK_data.csv")
df
# Out:
#      Unnamed: 0 Channel stim_cond  SPK_count
# 0             0   A-001         a          4
# 1             1   A-002         a          2
# 2             2   A-003         a          6
# 3             3   A-004         a          3
# 4             4   A-005         a          1
# ..          ...     ...       ...        ...
# 195         195   A-001         e          1
# 196         196   A-002         e          3
# 197         197   A-003         e          7
# 198         198   A-004         e          8
# 199         199   A-005         e          1
#
# [200 rows x 4 columns]

# %%
df["stderr"] = np.random.uniform(0.05,0.1,len(df))


df.head()
# Out:
#    Unnamed: 0 Channel stim_cond  SPK_count    stderr
# 0           0   A-001         a          4  0.076280
# 1           1   A-002         a          2  0.095615
# 2           2   A-003         a          6  0.075583
# 3           3   A-004         a          3  0.068258
# 4           4   A-005         a          1  0.069989

# %%
gf1["stderr"] = np.random.uniform(0.05,0.1,5)

# %%
df.head(50)
# Out:
#     Unnamed: 0 Channel stim_cond  SPK_count    stderr
# 0            0   A-001         a          4  0.076280
# 1            1   A-002         a          2  0.095615
# 2            2   A-003         a          6  0.075583
# 3            3   A-004         a          3  0.068258
# 4            4   A-005         a          1  0.069989
# 5            5   A-001         c          2  0.063617
# 6            6   A-002         c          3  0.050058
# 7            7   A-003         c         12  0.097838
# 8            8   A-004         c          7  0.053272
# 9            9   A-005         c          2  0.068040
# 10          10   A-001         b          6  0.076657
# 11          11   A-002         b          6  0.065695
# 12          12   A-003         b         19  0.065224
# 13          13   A-004         b         15  0.071313
# 14          14   A-005         b          0  0.066756
# 15          15   A-001         d          2  0.062457
# ...

# %%
from scipy.stats import sem

# %%
fig,axes = plt.subplots(df.Channel.nunique(),1,figsize=(10, 10))
channels = df.Channel.unique()

for channel,ax in zip(channels,axes):
    ax.errorbar(x = df.Channel.unique(),
                y = df[df['Channel']==channel].groupby('stim_cond')['SPK_count'].aggregate('mean'), 
                yerr=np.random.uniform(0.05,0.1,5),   
                label=channel,capsize=2,fmt ='o')

    ax.legend()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\sammasi\Miniconda3\envs\env-01\lib\site-packages\pandas\core\indexes\base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File c:\Users\sammasi\Miniconda3\envs\env-01\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\sammasi\Miniconda3\envs\env-01\lib\site-packages\pandas\_libs\index.pyx:142, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 195     True
# 196    False
# 197    False
# 198    False
# 199    False
# Name: Channel, Length: 200, dtype: bool, ['stim_cond'])' is an invalid key
#
# ...
