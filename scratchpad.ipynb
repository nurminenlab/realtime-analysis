# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

data_df = pd.read_csv("CH_stim_SPK_data.csv")
data_df.head(30)
# Out:
#     Unnamed: 0 Channel stim_cond  SPK_count
# 0            0   A-001         a          0
# 1            1   A-002         a          0
# 2            2   A-003         a          5
# 3            3   A-004         a          7
# 4            4   A-005         a          0
# 5            5   A-006         a          0
# 6            6   A-007         a         15
# 7            7   A-008         a          6
# 8            8   A-009         a          0
# 9            9   A-010         a          0
# 10          10   A-001         c          4
# 11          11   A-002         c          8
# 12          12   A-003         c         32
# 13          13   A-004         c         28
# 14          14   A-005         c          5
# 15          15   A-006         c          1
# 16          16   A-007         c         76
# 17          17   A-008         c         19
# 18          18   A-009         c          0
# 19          19   A-010         c          3
# ...

# %%
(data_df[data_df['Channel']=='A-003'].groupby('stim_cond')['SPK_count'].aggregate('mean')).index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object', name='stim_cond')

# %%
fig,axes = plt.subplots(data_df.Channel.nunique(),1,figsize=(10, 10))
channels = data_df.Channel.unique()

for ch,ax in zip(channels,axes):
    ax.errorbar(x = data_df[data_df['Channel']==ch].stim_cond.unique(),
                y = data_df[data_df['Channel']==ch].groupby('stim_cond')['SPK_count'].aggregate('mean'), 
                yerr=data_df[data_df['Channel']==ch].groupby('stim_cond')['SPK_count'].aggregate('sem'),   
                label=ch,capsize=2,fmt ='o')

    ax.legend()
    plt.tight_layout()

# %%
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(12, 8))
x_array = np.random.randn(6, 10)
y_array = np.random.randn(6, 10)

i = 0
for row in axes:
    for ax in row:
        x = x_array[i] 
        y = y_array[i]
        ax.scatter(x, y)
        ax.set_title("Plot " + str(i))
        i += 1
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

data_df = pd.read_csv("CH_stim_SPK_data.csv")
data_df.head(30)
# Out:
#     Unnamed: 0 Channel stim_cond  SPK_count
# 0            0   A-001         a          0
# 1            1   A-002         a          0
# 2            2   A-003         a          5
# 3            3   A-004         a          7
# 4            4   A-005         a          0
# 5            5   A-006         a          0
# 6            6   A-007         a         15
# 7            7   A-008         a          6
# 8            8   A-009         a          0
# 9            9   A-010         a          0
# 10          10   A-001         c          4
# 11          11   A-002         c          8
# 12          12   A-003         c         32
# 13          13   A-004         c         28
# 14          14   A-005         c          5
# 15          15   A-006         c          1
# 16          16   A-007         c         76
# 17          17   A-008         c         19
# 18          18   A-009         c          0
# 19          19   A-010         c          3
# ...

# %%
for ch in data_df['Channel'].unique():

    print(data_df[data_df['Channel']==ch].groupby('stim_cond')['SPK_count'].aggregate('mean') )
# Out:
# stim_cond
# a    5.625
# b    6.250
# c    7.250
# d    6.000
# e    5.750
# Name: SPK_count, dtype: float64
# stim_cond
# a    7.250
# b    7.375
# c    7.875
# d    8.375
# e    8.375
# Name: SPK_count, dtype: float64
# stim_cond
# a    24.500
# b    28.875
# c    29.375
# d    27.250
# e    27.375
# Name: SPK_count, dtype: float64
# stim_cond
# a    17.50
# b    21.00
# c    21.75
# d    17.50
# e    21.50
# Name: SPK_count, dtype: float64
# stim_cond
# a    3.125
# b    2.375
# c    2.500
# d    1.500
# e    2.250
# Name: SPK_count, dtype: float64
# stim_cond
# a    1.50
# b    2.00
# c    1.25
# d    1.00
# e    1.25
# Name: SPK_count, dtype: float64
# stim_cond
# a    63.000
# b    67.375
# c    72.375
# d    68.000
# e    69.000
# Name: SPK_count, dtype: float64
# stim_cond
# a    19.500
# b    21.875
# c    21.750
# d    21.875
# e    22.125
# Name: SPK_count, dtype: float64
# stim_cond
# a    0.625
# b    1.125
# c    0.875
# d    1.375
# e    0.750
# ...
